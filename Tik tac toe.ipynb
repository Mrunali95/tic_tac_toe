# %%
#Considering tic-tac-toe board like keypad


theBoard = {'7': ' ' , '8': ' ' , '9': ' ' ,
            '4': ' ' , '5': ' ' , '6': ' ' ,
            '1': ' ' , '2': ' ' , '3': ' ' }

            
def printBoard(board):
    print(board['7'] + '|' + board['8'] + '|' + board['9'])
    print('-+-+-')
    print(board['4'] + '|' + board['5'] + '|' + board['6'])
    print('-+-+-')
    print(board['1'] + '|' + board['2'] + '|' + board['3'])
    
printBoard(theBoard)
# Out:
#  | |
# -+-+-
#  | |
# -+-+-
#  | |

# %%
def game():

    turn = 'X'
    count = 0
    
    for i in range(10):
            printBoard(theBoard)
            print("It's your turn," + turn + ".Move to which place?")

            move = input()        

            if theBoard[move] == ' ':
                theBoard[move] = turn
                count += 1
            else:
                print("That place is already filled.\nMove to which place?")
                continue
                
        # Now we will check if player X or O has won,for every move after 5 moves. 
            if count >= 5:
                if theBoard['7'] == theBoard['8'] == theBoard['9'] != ' ': # across the top
                    printBoard(theBoard)
                    print("\nGame Over.\n")                
                    print(" **** " +turn + " won. ****")                
                    break
                elif theBoard['4'] == theBoard['5'] == theBoard['6'] != ' ': # across the middle
                    printBoard(theBoard)
                    print("\nGame Over.\n")                
                    print(" **** " +turn + " won. ****")
                    break
                elif theBoard['1'] == theBoard['2'] == theBoard['3'] != ' ': # across the bottom
                    printBoard(theBoard)
                    print("\nGame Over.\n")                
                    print(" **** " +turn + " won. ****")
                    break
                elif theBoard['1'] == theBoard['4'] == theBoard['7'] != ' ': # down the left side
                    printBoard(theBoard)
                    print("\nGame Over.\n")                
                    print(" **** " +turn + " won. ****")
                    break
                elif theBoard['2'] == theBoard['5'] == theBoard['8'] != ' ': # down the middle
                    printBoard(theBoard)
                    print("\nGame Over.\n")                
                    print(" **** " +turn + " won. ****")
                    break
                elif theBoard['3'] == theBoard['6'] == theBoard['9'] != ' ': # down the right side
                    printBoard(theBoard)
                    print("\nGame Over.\n")                
                    print(" **** " +turn + " won. ****")
                    break 
                elif theBoard['7'] == theBoard['5'] == theBoard['3'] != ' ': # diagonal
                    printBoard(theBoard)
                    print("\nGame Over.\n")                
                    print(" **** " +turn + " won. ****")
                    break
                elif theBoard['1'] == theBoard['5'] == theBoard['9'] != ' ': # diagonal
                    printBoard(theBoard)
                    print("\nGame Over.\n")                
                    print(" **** " +turn + " won. ****")
                    break 

            # If neither X nor O wins and the board is full, we'll declare the result as 'tie'.
            if count == 9:
                print("\nGame Over.\n")                
                print("It's a Tie!!")

            # we have to change the player after every move.
            if turn =='X':
                turn = 'O'
            else:
                turn = 'X'
                
board_keys = []

for key in theBoard:
    board_keys.append(key)
    
restart = input("Do want to play Again?(y/n)")

if restart == "y" or restart == "Y":  
    for key in board_keys:
        theBoard[key] = " "

    
    game()
# Out:
# Do want to play Again?(y/n)y
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# It's your turn,X.Move to which place?
# 7
# X| |
# -+-+-
#  | |
# -+-+-
#  | |
# It's your turn,O.Move to which place?
# 4
# X| |
# -+-+-
# O| |
# -+-+-
#  | |
# It's your turn,X.Move to which place?
# 5
# X| |
# -+-+-
# O|X|
# -+-+-
#  | |
# It's your turn,O.Move to which place?
# 3
# X| |
# -+-+-
# O|X|
# -+-+-
#  | |O
# It's your turn,X.Move to which place?
# 9
# X| |X
# -+-+-
# O|X|
# -+-+-
#  | |O
# It's your turn,O.Move to which place?
# 1
# X| |X
# -+-+-
# O|X|
# -+-+-
# O| |O
# It's your turn,X.Move to which place?
# 8
# X|X|X
# -+-+-
# O|X|
# -+-+-
# O| |O
#
# Game Over.
#
#  **** X won. ****

# %%
from tkinter import *
import tkinter.messagebox


ttt = Tk()
ttt.title("Tic_Tac_Toe")

bottomFrame = Frame(ttt, bd=7, width=10, height=100, relief= RIDGE)
bottomFrame.grid(row=1, column=0)
TopFrame = Frame(ttt, bd=5, width=10, height=20, relief= RIDGE)
TopFrame.grid(row=0, column=0)

buttons = StringVar()
click = True
count = 1

def results(count):
    if count >= 5:
        if btn7['text'] == btn8['text'] == btn9['text'] != " ":
            w = str(btn7['text'])
            btn7.configure(bg="pale green")
            btn8.configure(bg="pale green")
            btn9.configure(bg="pale green")
            tkinter.messagebox.showinfo("Game Over", w+" is winner!")
        elif btn4['text'] == btn5['text'] == btn6['text'] != " ":
            w = str(btn4['text'])
            btn4.configure(bg="pale green")
            btn5.configure(bg="pale green")
            btn6.configure(bg="pale green")
            tkinter.messagebox.showinfo("Game Over", w+" is winner!")
        elif btn1['text'] == btn2['text'] == btn3['text'] != " ":
            w = str(btn1['text'])
            btn1.configure(bg="pale green")
            btn2.configure(bg="pale green")
            btn3.configure(bg="pale green")
            tkinter.messagebox.showinfo("Game Over", w+" is winner!")
        elif btn7['text'] == btn4['text'] == btn1['text'] != " ":
            w = str(btn7['text'])
            btn7.configure(bg="pale green")
            btn4.configure(bg="pale green")
            btn1.configure(bg="pale green")
            tkinter.messagebox.showinfo("Game Over", w+" is winner!")
        elif btn8['text'] == btn5['text'] == btn2['text'] != " ":
            w = str(btn8['text'])
            btn8.configure(bg="pale green")
            btn5.configure(bg="pale green")
            btn2.configure(bg="pale green")
            tkinter.messagebox.showinfo("Game Over", w+" is winner!")
        elif btn9['text'] == btn6['text'] == btn3['text'] != " ":
            w = str(btn9['text'])
            btn9.configure(bg="pale green")
            btn6.configure(bg="pale green")
            btn3.configure(bg="pale green")
            tkinter.messagebox.showinfo("Game Over", w+" is winner!")
        elif btn7['text'] == btn5['text'] == btn3['text'] != " ":
            w = str(btn7['text'])
            btn7.configure(bg="pale green")
            btn5.configure(bg="pale green")
            btn3.configure(bg="pale green")
            tkinter.messagebox.showinfo("Game Over", w+" is winner!")
        elif btn9['text'] == btn5['text'] == btn1['text'] != " ":
            w = str(btn9['text'])
            btn9.configure(bg="pale green")
            btn5.configure(bg="pale green")
            btn1.configure(bg="pale green")
            tkinter.messagebox.showinfo("Game Over", w+" is winner!")
        elif count == 9:
             tkinter.messagebox.showinfo("Game Over", "It's a TIE!")
    
            

def btnclick(buttons):
    global click
    global count
    if buttons["text"] == " " and click==True:
        buttons["text"] = "X"
        results(count)
        click = False
        count += 1
    elif buttons["text"] == " " and click==False:
        buttons["text"] = "O"
        results(count)
        click = True
        count += 1
        
def reset():
    btn7['text'] = " "
    btn8['text'] = " "
    btn9['text'] = " "
    btn4['text'] = " "
    btn5['text'] = " "
    btn6['text'] = " "
    btn1['text'] = " "
    btn2['text'] = " "
    btn3['text'] = " "
    
    btn4.configure(bg="powder blue")
    btn5.configure(bg="powder blue")
    btn6.configure(bg="powder blue")
    btn7.configure(bg="powder blue")
    btn8.configure(bg="powder blue")
    btn9.configure(bg="powder blue")
    btn1.configure(bg="powder blue")
    btn2.configure(bg="powder blue")
    btn3.configure(bg="powder blue")
            
            
def exit():
    iexit = tkinter.messagebox.askyesno("Tic Tac Toe", "Confirm you want to exit?")
    if iexit > 0:
        ttt.destroy()
        return


btn7 = Button(TopFrame, fg="black", width = 4, height= 2, font=('arial',20,'bold'), text = " ", bg='powder blue', command=lambda:btnclick(btn7))
btn7.grid(row=1, column=0)
btn8 = Button(TopFrame, fg="black", width = 4, height= 2, font=('arial',20,'bold'), text = " ", bg='powder blue', command=lambda:btnclick(btn8))
btn8.grid(row=1, column=1)
btn9 = Button(TopFrame, fg="black", width = 4, height= 2, font=('arial',20,'bold'), text = " ", bg='powder blue', command=lambda:btnclick(btn9))
btn9.grid(row=1, column=2)
btn4 = Button(TopFrame, fg="black", width = 4, height= 2, font=('arial',20,'bold'), text = " ", bg='powder blue', command=lambda:btnclick(btn4))
btn4.grid(row=2, column=0)
btn5 = Button(TopFrame, fg="black", width = 4, height= 2, font=('arial',20,'bold'), text = " ", bg='powder blue', command=lambda:btnclick(btn5))
btn5.grid(row=2, column=1)
btn6 = Button(TopFrame, fg="black", width = 4, height= 2, font=('arial',20,'bold'), text = " ", bg='powder blue', command=lambda:btnclick(btn6))
btn6.grid(row=2, column=2)
btn1 = Button(TopFrame, fg="black", width = 4, height= 2, font=('arial',20,'bold'), text = " ", bg='powder blue', command=lambda:btnclick(btn1))
btn1.grid(row=3, column=0)
btn2 = Button(TopFrame, fg="black", width = 4, height= 2, font=('arial',20,'bold'), text = " ", bg='powder blue', command=lambda:btnclick(btn2))
btn2.grid(row=3, column=1)
btn3 = Button(TopFrame, fg="black", width = 4, height= 2, font=('arial',20,'bold'), text = " ", bg='powder blue', command=lambda:btnclick(btn3))
btn3.grid(row=3, column=2)

reset = Button(bottomFrame, fg="black", width = 6, height= 2, font=('arial',20,'bold'), text = "Reset", bg='powder blue', command=reset)
reset.grid(row=3, column=1)
exit = Button(bottomFrame, fg="black", width = 6, height= 2, font=('arial',20,'bold'), text = "Exit", bg='powder blue', command=exit)
exit.grid(row=3, column=2)

ttt.mainloop()
